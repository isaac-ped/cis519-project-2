# %%
#!pip install -q --upgrade pandas
import torch
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from pprint import pprint
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable
import pandas as pd

#projects1_1 = pd.read_csv('kickstarter-projects/ks-projects-201612.csv', encoding='latin1')
projects1 = pd.read_csv('kickstarter-projects/ks-projects-201801.csv')
projects2 = pd.read_csv('funding-successful-projects-on-kickstarter/train.csv')

# %%
pd.__version__
# Out:
# '0.22.0'

# %%
projects = projects1.merge(projects2, on='name', how='inner')
projects = projects.dropna()
projects.columns
# Out:
# Index(['ID', 'name', 'category', 'main_category', 'currency_x', 'deadline_x',
#        'goal_x', 'launched', 'pledged', 'state', 'backers', 'country_x',
#        'usd pledged', 'usd_pledged_real', 'usd_goal_real', 'project_id',
#        'desc', 'goal_y', 'keywords', 'disable_communication', 'country_y',
#        'currency_y', 'deadline_y', 'state_changed_at', 'created_at',
#        'launched_at', 'backers_count', 'final_status'],
#       dtype='object')

# %%
import numpy as np

renames = {
    'country_x': 'country',
    'currency_x': 'currency',
    'usd_goal_real': 'goal',
    'usd_pledged_real': 'pledged',
    'country_y': 'country',
    'currency_y': 'currency',
    'deadline_y': 'deadline',
    'backers_count': 'backers'
}

to_num = lambda x: pd.to_numeric(x, errors='coerce')
to_date = lambda x: pd.to_datetime(x, unit='s')
conversions = {
    'backers': to_num,
    'deadline': to_date,
    'launched_at': to_date,
    'state_changed_at': to_date,
    'created_at': to_date,
    'goal': to_num,
    'pledged': to_num,
}

drops = (
    'ID', 'project_id', 'keywords', 'deadline_x', 
    'disable_communication', 
    'goal_x', 'goal_y', 'usd pledged'
)

# %%
def clean_df(df, renames=None, retypes=None, drops=None):
    if renames is not None:
        for orig, new in renames.items():
            if new in df.columns:
                diffs = df[[orig, new]][df[orig] != df[new]]
                print("The following columns showed differences when renaming!")
                print(diffs[:10])
                df[new] = df[orig]
                df = df.drop(orig, axis=1)
            else:
                df = df.rename(columns={orig: new})
    if retypes is not None:
        for col, conv in retypes.items():
            dfcol = df[col]
            df = df.drop(col, axis=1)
            df[col] = conv(dfcol)
    if drops is not None:
        for col in drops:
            df = df.drop(col, axis=1)
            
    df = df.dropna(axis=1, how='all')
    df = df.dropna(axis=0, how='any')
    return df
            
cleaned = clean_df(projects, renames, conversions, drops)
# Out:
# The following columns showed differences when renaming!
#     usd_pledged_real  pledged
# 4               6.29     48.0
# 5           42174.03  48905.0
# 6              31.09     21.0
# 25              2.36      3.0
# 29           9110.34  11336.0
# 40           1122.89    756.0
# 44            485.72    293.0
# 47             16.58     10.0
# 49            628.47    656.0
# 57           4848.23   3097.0
# The following columns showed differences when renaming!
#     country_y country
# 109        US      GB
# 128        US      GB
# 345        US      CA
# 347        US      GB
# 398        US      GB
# 399        US      GB
# 416        CA      US
# 432        US      CA
# 863        US      AU
# 896        GB      US
# The following columns showed differences when renaming!
#     currency_y currency
# 109        USD      GBP
# 128        USD      GBP
# 345        USD      CAD
# 347        USD      GBP
# 398        USD      GBP
# 399        USD      GBP
# 416        CAD      USD
# 432        USD      CAD
# 863        USD      AUD
# 896        GBP      USD
# The following columns showed differences when renaming!
#      backers_count  backers
# 58             142        7
# 109             12        2
# 128              5       90
# 135             67        0
# 136              3        0
# 139              3       67
# 140              0       67
# 141             67        3
# 143              0        3
# 144             67        6

# %%
from scipy import stats

cleaned['desc_len'] = cleaned.desc.str.len()

try:
    ######################
    ## I'm filtering out projects that lasted less than a day. 
    ## (Seems to be about 1,000 of them)
    ######################
    cleaned['duration'] = cleaned['deadline'] - cleaned['launched_at']
    real_duration = cleaned['state_changed_at'] - cleaned['launched_at']
    cleaned = cleaned[real_duration > pd.Timedelta(days=1)]
except Exception:
    print("Couldn't create duration or filter dataset")
    pass

cleaned = cleaned[cleaned['goal'] > 100]
cleaned = cleaned[cleaned['goal'] <= 2e6]
cleaned = cleaned[(cleaned.state == 'successful') | (cleaned.state == 'failed')]
cleaned = cleaned[(cleaned.country == 'US')]
cleaned = cleaned[cleaned['desc_len'] > 50]
cleaned = cleaned.sort_values("created_at")

# %%
pd.pivot_table(cleaned, columns=['country'])
# Out:
# country                 US
# backers         144.996844
# desc_len        133.770953
# final_status      0.348684
# goal          18459.986030
# pledged       11655.068268

# %%
pd.pivot_table(cleaned, columns=['state'])
# Out:
# state               failed    successful
# backers          20.102859    280.126837
# desc_len        133.793887    133.746140
# final_status      0.006049      0.719399
# goal          26206.518525  10078.566488
# pledged        1423.177530  22725.539997

# %%
cleaned.groupby('country').size()
# Out:
# country
# US    77936
# dtype: int64

# %%
import traceback

def cannot_crash(fn):
    def inner(*args, **kwargs):
        try:
            return fn(*args, **kwargs)
        except Exception:
            print(traceback.format_exc())
    return inner

# %%
import numpy as np
import matplotlib.pyplot as plt

@cannot_crash
def summarize(df):
    n_failed = np.count_nonzero(df.state == 'failed')
    print("{} Failed".format(n_failed))
    n_success = np.count_nonzero(df.state == 'successful')
    print("{} Success".format(n_success))
 
@cannot_crash
def hist_by_group(df, groupname, n_groups=None):
    if n_groups is None:
        grouped = df.groupby(groupname)
        names = grouped.groups.keys()
    else:
        pcts = np.arange(0, 1, 1/float(n_groups))
        quantiles = df[groupname].quantile(pcts)
        inds = np.digitize(df[groupname], quantiles)
        grouped = df.groupby(inds)
        names = []
        for a, b in zip(pcts, pcts[1:]):
            names.append('{}-{}'.format(quantiles[a], quantiles[b]))
        names.append('{}-{}'.format(quantiles[b], max(df[groupname])))
    
    num_groups = len(grouped)
    
    successes = []
    failures = []

    margins = []
    totals = []
    
    for name, group in grouped:

        n_failed = np.count_nonzero(group.state == 'failed')
        n_success = np.count_nonzero(group.state == 'successful')
        successes.append(float(n_success) / len(group))
        failures.append(float(n_failed) / len(group))
        
        margins.append(np.abs(n_success - n_failed))
        totals.append(n_success + n_failed)
    
    
    
    bar_width = .25
    indices = np.arange(num_groups)
    
    plt.bar(indices, successes, bar_width, color='g', label='succes')
    plt.bar(indices + bar_width, failures, bar_width, color='r', label='failures')
    plt.xticks(indices + bar_width * 1.5, names)
    plt.gca().set_ylabel("Percentage")
    plt.gca().set_xlabel(groupname)
    plt.legend()
   
@cannot_crash
def rolling_success(df):
    
    statuses = df[(df['state'] == 'failed') | (df['state'] == 'successful')]
    
    statuses['succeeded'] = statuses['state'] == 'successful'
    
    grouped = statuses.groupby((statuses['goal'] / 1000).astype(int))

    not_alone = grouped.size() > 10
    
    success_rate = grouped['succeeded'].mean()[not_alone]
    
    ax = plt.subplot()
    print(success_rate.shape)
    plt.plot(success_rate.index, success_rate, '.')
    ax.set_xscale('log')
    ax.set_xlabel("Goal")
    ax.set_ylabel("Success Ratio")

@cannot_crash
def success_over_time(df, col):
    creations = df['created_at'].astype(np.int64)
    quantiles = creations.quantile(np.arange(0, 1, .1))
    inds = np.digitize(creations, quantiles)
    grouped = df.groupby(inds)
    
    unique_cols = df[col].unique()
    
    dates = []
    data = []
    names = []
    for unique_col in unique_cols:
        col_data = []
        for _, group in grouped:
            group = group[group[col] == unique_col]
            n_failed = np.count_nonzero(group.state == 'failed')
            n_success = np.count_nonzero(group.state == 'successful')
            col_data.append(float(n_success) / len(group))
        data.append(col_data)
        names.append(unique_col)

    all_data = []
    for _, group in grouped:
        n_failed = np.count_nonzero(group.state == 'failed')
        n_success = np.count_nonzero(group.state == 'successful')
        all_data.append(float(n_success) / len(group))

        
    for q in quantiles:
        dates.append(np.datetime64(int(q), 's'))
        
    fig, ax = plt.subplots()
    for dat in data:
        ax.plot(dates, dat)
    
    ax.plot(dates, all_data, 'k', linewidth=3)
    
    plt.legend(names + ['All'])
    plt.show()

# %%
# %matplotlib notebook

success_over_time(cleaned, 'main_category')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook

summarize(cleaned)
plt.figure(figsize=(15, 4))
hist_by_group(cleaned, 'main_category')
plt.tight_layout()

plt.figure()
rolling_success(cleaned)
# Out:
# 40502 Failed
# 37434 Success
# <img src="data:image/png;base64,..." width="1500">
# <img src="data:image/png;base64,..." width="640">
# (105,)

# %%
@cannot_crash
def show_goal_hist():
    fig, ax = plt.subplots()
    ax.hist(np.log(cleaned['goal']), 50)
    plt.show()
    plt.xlabel("log(USD Goal)")
    plt.title("Distribution of goals in US $")
    
show_goal_hist()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
@cannot_crash
def goal_percent_comparison(successes, failures, canceled=None):
    ax = plt.subplot()
    plt.plot(successes.goal, successes.pledged/successes.goal, 'g.', alpha=.2)
    plt.plot(failures.goal, failures.pledged/failures.goal, 'r.', alpha=.2)
    if canceled is not None:
        plt.plot(canceled.goal, canceled.pledged/canceled.goal, 'y.', alpha=.2)
    ax.set_xscale('log')
    ax.set_xlabel('Goal')
    ax.set_ylabel('% Of Goal Reached')
    plt.ylim([0, 2])
    plt.legend(['successes','failures', 'canceled'])

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

plt.figure()
successes = cleaned[cleaned.state == 'successful']
failures = cleaned[cleaned.state == 'failed']
canceled = cleaned[cleaned.state == 'canceled']

goal_percent_comparison(successes,failures, canceled)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import copy
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import nltk
import re

wnl = WordNetLemmatizer()
def get_wordnet_pos(treebank_tag):

    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return ''

n_lemmatized = 0    
def lemmatize_text(text):
    global n_lemmatized
    if n_lemmatized % 10000 == 0:
        print(".", end='', flush=True)
    n_lemmatized+= 1
        
    words = []
    for word, pos in nltk.pos_tag(word_tokenize(text)):
        word = word.lower()
        pos = get_wordnet_pos(pos)
        if pos != '':
            words.append(wnl.lemmatize(word, pos))
        elif re.match("[a-z-]+'?[a-z]*", word):
            words.append(wnl.lemmatize(word))
    return ' '.join(words)

def do_lemmatize(df):
    df = copy.deepcopy(df)

    print("Lemmatizing description (this will take a while)")
    df['desc'] = df['desc'].apply(lemmatize_text)
    print("Lemmatizing name (this will take a while)")
    df['name'] = df['name'].apply(lemmatize_text)
    return df
    
lemmatized = do_lemmatize(cleaned)
# Out:
# Lemmatizing description (this will take a while)
# ........Lemmatizing name (this will take a while)
# ........

# %%
lemmatized
# Out:
#                                                      name          category  \
# 0                                           where be hank    Narrative Film
# 2                                               the beard       Comic Books
# 3                            note from london above below         Art Books
# 7                                                  bb130a        Public Art
# 8                                 arrow sound debut album        Indie Rock
# 9                   help scott reynolds make a new record        Indie Rock
# 10                   the please please me studio premiere               Pop
# 11                                  hot chicken take over       Restaurants
# 12                                   star and the snowman    Narrative Film
# 13                                            sea of iron    Tabletop Games
# 14       mother into living fit yoga dvd for mom and baby            Family
# 15                       mobile barbecue catering trailer       Food Trucks
# 16                     the fanalyzers view from the stand         Webseries
# 17                                           hiit bottle™            Drinks
# 18                                       secular solstice         Festivals
# 19                                      road to the shire       Documentary
# 20                       spiral electric skylab recording              Rock
# 21                                          my coffee box            Drinks
# 22                                 the dark water project        Indie Rock
# 23                             bob contemplate end it all            Shorts
# 24                                      the girl bathroom         Webseries
# 26                                            new lasagna       Restaurants
# 27                       just another reality show season         Webseries
# 28                           backroads ep processing cost  Electronic Music
# 30       patty at the party - a mumblecore horror feature         Webseries
# 31                                          happy fix usa           Apparel
# 32                  be part of the next smb project album        Indie Rock
# 33        jane brown a story of courage survival and love       Periodicals
# 34              serino pizza rolling pizza lab food truck       Food Trucks
# 35                                   operation make stuff       Video Games
# ...                                                   ...               ...
# 102675  an original country music ep from the weal and...    Country & Folk
# 102676                                         canterbury    Tabletop Games
# 102677  the kissing bandit child book puppet with a twist  Children's Books
# 102679  when age have no leash lesson learn from senio...           Animals
# 102680       hybrid a local art production group art show        Public Art
# 102681  cnc bt15/iso15 atc spindle cartridge and spind...          Hardware
# 102682                  cthulhu chaos - unique dice tower    Tabletop Games
# 102684                              an island on the page            Poetry
# 102685  art culture and development build an art/music...      Illustration
# 102686                                 bean bite lunchbox       Food Trucks
# 102687                               help unrb go on tour              Rock
# 102691  no.1 fan a community connect people through in...              Apps
# 102693  let pretend we 're christian and play in the snow        Nonfiction
# 102694                                      object attack    Narrative Film
# 102695                                       doozy the ep              Rock
# 102697                              the mangled re-launch    Narrative Film
# 102698                                  thesis exhibition       Mixed Media
# 102699                             kronos under project /   Classical Music
# 102701      language of love - a new cd from lisa deveaux        Indie Rock
# 102685 2015-01-25 00:33:24  20000.0       3.00       135 30 days 00:00:00
# 102686 2014-08-29 20:32:50   1200.0       0.00       108 30 days 00:00:00
# 102687 2012-05-24 07:24:03   1000.0    2035.05       127 38 days 03:49:12
# 102691 2014-06-17 13:55:14  75000.0    2645.00       132 20 days 00:00:00
# 102693 2013-03-15 17:00:43  15000.0     225.00       131 25 days 00:00:00
# 102694 2011-05-28 15:16:31   5500.0    6023.00       130 30 days 00:00:00
# 102695 2011-07-07 19:20:16   1000.0     661.00       102 30 days 00:00:00
# 102697 2013-09-15 18:30:56   5000.0   15052.00       118 45 days 01:00:00
# 102698 2013-02-04 21:39:44   8000.0    8935.00       133 29 days 23:00:00
# 102699 2011-12-08 00:09:55  10000.0   12300.00       124 50 days 05:40:59
# 102701 2011-02-03 01:15:10   5000.0    5025.00       135 60 days 23:00:00
# 102702 2013-05-23 23:56:24  10000.0    4676.00       128 39 days 20:34:36
# 102703 2014-07-03 14:45:31  30000.0   42647.00        75 31 days 23:48:12
# 102704 2012-02-03 22:11:34  10000.0   10300.00       113 59 days 23:00:00
# 102705 2014-04-14 14:12:21  12000.0    2090.00       127 30 days 00:00:00
# 102706 2014-10-29 18:28:22  25000.0   11643.00       103 29 days 10:43:43
# 102708 2014-07-11 07:34:43   5000.0      18.00       120 31 days 00:00:00
# 102710 2013-10-16 17:03:08    950.0    1732.02       115 42 days 22:27:56
# 102711 2012-06-12 21:44:21   4999.0     980.00       133 30 days 00:00:00
# 102714 2011-06-15 19:14:48   1500.0     155.00       128 27 days 00:00:00
# 102715 2010-06-25 23:15:55  15000.0      20.00        71 45 days 10:18:30
# 102716 2011-07-16 19:16:45   2000.0     524.00       124 28 days 00:00:00
#
# [77936 rows x 18 columns]

# %%
cleaned.created_at.iloc[0] > cleaned.created_at.iloc[1] - pd.Timedelta('180 days')
# Out:
# False

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

vectorizer.fit(lemmatized.desc.map(str) + " " + lemmatized.name)

desc_full_tfidf = vectorizer.transform(lemmatized.desc)
name_full_tfidf = vectorizer.transform(lemmatized.name)

# %%
print(lemmatized.desc.iloc[9])
print(desc_full_tfidf[9,:][desc_full_tfidf[9,:].nonzero()])
# Out:
# a good navy be not a provocation to war it be the sure guaranty of peace — president theodore roosevelt
# [[0.19043576 0.06006563 0.35720079 0.05048015 0.25808761 0.33757285
#   0.40582363 0.28214019 0.23126984 0.06302549 0.17110572 0.30645161
#   0.10962215 0.40582363 0.17547973 0.13028607]]

# %%
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(100)
desc_svd = svd.fit_transform(desc_full_tfidf)
name_svd = svd.fit_transform(name_full_tfidf)

text_svd = np.concatenate([desc_svd, name_svd], 1)

# %%
import sklearn.preprocessing
scaled_svd = sklearn.preprocessing.scale(text_svd)

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import nltk
from __future__ import print_function
import sys
import re
from sklearn.feature_extraction import DictVectorizer
from collections import defaultdict

wnl = WordNetLemmatizer()

def create_feature_matrix(df,
                          scalars=None,
                          percentiles = None,
                          categoricals=None,
                          splits=None):
    # Should be done using apply or map or something like that
    ds = []
    Y = []
    grps = {}
    
    sorted_pcts = {}
    print("Sorting necessary columns")
    if percentiles:
        for pct in percentiles:
            sorted_pcts[pct] = np.array(sorted(df[pct]))
     
    ds = []   
    
    print("Iterating over rows ")
    for i, r in df.iterrows():
        if i % 10000 == 0:
            print('.', end='')
            sys.stdout.flush()
        d = defaultdict(int)
        if percentiles is not None:
            for pct in percentiles:
                d[pct] = float(np.searchsorted(sorted_pcts[pct], r[pct])) / len(sorted_pcts[pct])
        
        if scalars is not None:
            for sca in scalars:
                try:
                    d[sca] = pd.to_numeric(r[sca])
                except:
                    raise
                    print(":O", sca, d[sca])
                    continue
                           
        if categoricals is not None:
            for cat in categoricals:
                d[cat + r[cat]] = 1
                
        if splits is not None:
            for spl in splits:
                for word in r[spl].split():
                    d[spl+'_'+word.upper()] = 1
                
        ds.append(d)
    
    v = DictVectorizer()
    print("Vectorizing")
    X = v.fit_transform(ds)
    return X.astype(float), v.feature_names_

# %%
from sklearn.preprocessing import normalize

numerical_features = create_feature_matrix(cleaned,
    percentiles = ('goal', 'created_at', 'desc_len', 'duration'),
    categoricals = ('category', 'main_category', 'country',)
)
numerical_features, feature_names = numerical_features
# Out:
# Sorting necessary columns
# Iterating over rows
# .......Vectorizing

# %%
numerical_features, feature_names = numerical_features

# %%
A = np.random.rand(1, 5000)
B = np.random.rand(1000, 5000)

da = np.mean(np.dot(A, B.T))
mB = np.mean(B, 0)
db = np.dot(A, mB.T)
# Out:
# array([0.])

# %%
success_mask = cleaned.state == 'successful'
fail_mask = cleaned.state == 'failed'

succ_svd = text_svd[success_mask]
succ_svd_df = pd.DataFrame(succ_svd, index=cleaned[success_mask].created_at)

fail_svd = text_svd[fail_mask]
fail_svd_df = pd.DataFrame(fail_svd, index=cleaned[fail_mask].created_at)

succ_mean = succ_svd_df.rolling(pd.Timedelta("180 days")).mean()
fail_mean = fail_svd_df.rolling(pd.Timedelta("180 days")).mean()

full_success_mean = np.empty((len(cleaned), 200))
full_success_mean[:] = np.nan
full_success_mean[success_mask] = succ_mean
full_success_mean = pd.DataFrame(full_success_mean).fillna(method='ffill').fillna(method='bfill').values

full_fail_mean = np.empty((len(cleaned), 200))
full_fail_mean[:] = np.nan
full_fail_mean[fail_mask] = fail_mean
full_fail_mean = pd.DataFrame(full_fail_mean).fillna(method='ffill').fillna(method='bfill').values

# %%
success_sim = []
failed_sim = []

for i, (instance, s_m, f_m)  in enumerate(zip(text_svd, full_success_mean, full_fail_mean)):
    success_sim.append(np.dot(instance, s_m))
    failed_sim.append(np.dot(instance, f_m))
    
success_sim = np.array(success_sim)
failed_sim = np.array(failed_sim)

# %%
sim_features = np.concatenate([success_sim.reshape(-1, 1), failed_sim.reshape(-1,1)], 1)
sim_features
# Out:
# array([[0.2655324 , 0.01357679],
#        [0.01357679, 0.19918607],
#        [0.52747837, 0.04076437],
#        ...,
#        [0.02065392, 0.02413838],
#        [0.02095197, 0.02335977],
#        [0.02470739, 0.02778879]])

# %%
cleaned.iloc[np.argsort(failed_sim)]
# Out:
#                                                      name          category  \
# 89211                      As porempor molessi temporibus       Periodicals
# 3681                          Maximus Thor : Yellow Magic            Comedy
# 6957                                Encuentro de Artistas        Public Art
# 94190                       Anthony T- Entrego mi Corazon       World Music
# 31737                                             PEELERS    Narrative Film
# 6863                                       Kitty's Corner      Experimental
# 46466   URKU WASI - CABAÑAS DE DESCANSO EN LA MONTAÑA ...      Architecture
# 68796                                          Trent Edin           Hip-Hop
# 43163                                     Virtue Pedalist           Gadgets
# 45232                        SITGREEN Cardboard Furniture    Product Design
# 71088                      Frameable, shareable postcards          Fine Art
# 79016                                         Killer Todd         Webseries
# 66479   Operation Linebacker I/II Commemorative Challe...    Product Design
# 77920                 HermitCraft PE donation kickstarter      Mobile Games
# 58386                                  Triniti Illuminati    Conceptual Art
# 21367                              Programmable Capacitor          Hardware
# 1999                                      Cthulhu Wars VF    Tabletop Games
# 16291                                    InTuition Pencil    Product Design
# 43857                                           CandyLand         Webseries
# 39400                        GoTabs Portable Sports Drink            Drinks
# 39452                          Astrophotography with Noah            Nature
# 90923               PJ reefs Miniature Saltwater Aquarium    Product Design
# 72457                                     Shark Kage Ramp    Product Design
# 36805                                             Visible             Drama
# 22654     Subdued Green Mountain Boys Flag Morale Patches    Graphic Design
# 54098   Noble Timepieces - Limited Swiss Movement Watches    Product Design
# 31953                   TwoSense - Mission to Commission!   Classical Music
# 69676    Green Mountain Boys Standard Flag Morale Patches    Graphic Design
# 53106                   21st Century Hendrix Presentation              Rock
# 17524                 Limited Edition PADG Flat-Brim: 001           Apparel
# ...                                                   ...               ...
# 89496   Blameshift: Let's Make An Album Together & Go ...              Rock
# 23714          Release the Debut Snocap Summer EP Album!!        Indie Rock
# 997     Help Produce the Brand New ILLUS Album and Com...           Hip-Hop
# 18133                    Help Fund A Sweet New Video Game       Video Games
# 44802                                     The 140 Project       Documentary
# 101190  Help Darkhorse record their first full length ...              Rock
# 30602                       The Mothership's Second Album              Rock
# 80586     Make This The Rescue's first full length album!              Rock
# 15697   Be a Part of Third Time's a Charm's first Full...              Rock
# 20110                        The First Times Record an EP              Rock
# 100609         Innovating the way how children learn math       Video Games
# 73206   Chris Schutz + Tourists Hit the Road and Go On...        Indie Rock
# 56348   ALL OF US release The Product's NEW record, YO...              Rock
# 22736   Help THE RELAY COMPANY make a new MUSIC VIDEO ...        Indie Rock
# 46843   Record, Release, and Promote the new In the Au...           Hip-Hop
# 32670                                   N&V MAKE AN ALBUM              Rock
# 40881   Put B.A. The Gift In The Recording Studio - Ho...           Hip-Hop
# 37291                Be A Part Of The Exchange's New EP!!              Rock
# 50876                       The Music for America Project        Indie Rock
# 17772                                  Start my studio!!!    Graphic Design
# 48111   HAPPY VALLEY: Dexter meets 6 Feet Under. For t...    Narrative Film
# 65595          Help Launch Cities and Saints Debut Album!               Pop
# 93793                           iGoozex - Free iPhone app          Software
# 44488     This Charming Man: A Children's Book For Adults  Children's Books
# 48769                                     Cities x Design    Graphic Design
# 4937    No-bit: An artist book of analog drawings insp...      Illustration
# 9797                          Smogr Alert Field Recording    Graphic Design
# 1406  2015-03-31 20:18:54    6500.0       1.00       113 34 days 19:41:01
# 1238  2015-03-31 20:18:54    3000.0     367.00       113 34 days 19:41:01
# 1392  2015-03-31 20:18:54    2500.0      56.00       113 34 days 19:41:01
# 1217  2015-03-31 20:18:54    3000.0     123.00       113 34 days 19:41:01
# 1224  2015-03-31 20:18:54    3000.0    3106.00       113 34 days 19:41:01
# 1140  2015-03-31 20:18:54    3500.0       1.00       113 34 days 19:41:01
# 1280  2015-03-31 20:18:54    5000.0       1.00       113 34 days 19:41:01
# 1210  2015-03-31 20:18:54    3800.0      16.00       113 34 days 19:41:01
# 22847 2009-08-25 20:35:59    1250.0    1590.00        81 31 days 07:07:52
# 65595 2010-05-08 11:13:01    1000.0    1026.00       150 50 days 05:40:01
#
# [77936 rows x 18 columns]

# %%
text_and_numerical_features = np.concatenate([numerical_features.todense(), text_svd], 1)

# %%
import sklearn.preprocessing

scaled_numerical_features = sklearn.preprocessing.scale(numerical_features.todense())
scaled_text_and_numerical = sklearn.preprocessing.scale(text_and_numerical_features)
sim_text_and_numerical = np.concatenate([scaled_text_and_numerical, scaled_sim], 1)

# %%
text_and_scaled_numerical = np.concatenate([scaled_numerical_features, scaled_svd], 1)

# %%
sim_and_scaled_numerical = np.concatenate([scaled_numerical_features, scaled_sim.reshape(-1,1)],1)

# %%
all_features = create_feature_matrix(cleaned,
    percentiles = ('goal', 'created_at', 'desc_len', 'duration'),
    categoricals = ('category', 'main_category', 'country',),
    splits = ('desc', 'name',)
)
all_features
# Out:
# Sorting necessary columns
# Iterating over rows
# ..........Vectorizing
# <99976x222097 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3051757 stored elements in Compressed Sparse Row format>

# %%
date_converted = copy.copy(succ_fail_only)
date_converted['duration'] = date_converted['duration'].astype(int)
date_converted['goal'] = np.log(date_converted['goal'])
date_converted['desc_len'] = np.log(date_converted['desc_len'])
date_converted['duration'] = np.log(date_converted['duration'])
features_no_text = create_feature_matrix(date_converted, 
    scalars = ('goal',  'desc_len', 'duration'),
    percentiles = ('created_at',),
    categoricals = ('category', 'main_category', 'country')
)
features_no_text
# Out:
# Sorting necessary columns
# Iterating over rows
# .........Vectorizing
# <94928x187 sparse matrix of type '<class 'numpy.float64'>'
# 	with 664483 stored elements in Compressed Sparse Row format>

# %%
all_features_succ_fail_only = create_feature_matrix(succ_fail_only,
    percentiles = ('goal', 'created_at', 'desc_len', 'duration'),
    categoricals = ('category', 'main_category', 'country',),
    splits = ('desc', 'name',)
)
all_features_succ_fail_only
# Out:
# Sorting necessary columns
# Iterating over rows
# .........Vectorizing
# <94928x141789 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3132142 stored elements in Compressed Sparse Row format>

# %%
no_desc = create_feature_matrix(cleaned,
    percentiles = ('goal', 'duration'),
    categoricals = ('category', 'main_category', 'country',),
    splits = ('name',)
)
no_desc
# Out:
# Sorting necessary columns
# Iterating over rows ..........Vectorizing
# <99976x86389 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1043228 stored elements in Compressed Sparse Row format>

# %%
all_features_no_date = create_feature_matrix(cleaned,
    percentiles = ('goal', 'desc_len'),
    categoricals = ('category', 'main_category', 'country',),
    splits = ('desc', 'name',)
)
all_features_no_date
# Out:
# Sorting necessary columns
# Iterating over rows ..........Vectorizing
# <99976x222095 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2851810 stored elements in Compressed Sparse Row format>

# %%
from sklearn.preprocessing import normalize
import copy
logged = copy.deepcopy(succ_fail_only)
logged['goal'] = np.log(logged['goal'])
features_no_text = create_feature_matrix(logged,
    percentiles = ('created_at',),
    scalars = ('desc_len', 'goal'),
    categoricals = ('category', 'main_category', 'country')
)
features_no_text
# Out:
# Sorting necessary columns
# Iterating over rows
# .........Vectorizing
# <94928x186 sparse matrix of type '<class 'numpy.float64'>'
# 	with 569567 stored elements in Compressed Sparse Row format>

# %%
from sklearn.preprocessing import normalize

text_features_only = create_feature_matrix(succ_fail_only,
    splits = ('desc', 'name')
)
text_features_only
# Out:
# Sorting necessary columns
# Iterating over rows
# .........Vectorizing
# <94928x214485 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2234777 stored elements in Compressed Sparse Row format>

# %%
import time
import numpy as np
import sklearn
from sklearn.svm import LinearSVC
from sklearn.feature_extraction import DictVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.model_selection import cross_val_score

@cannot_crash
def run_classifier(X, Y, clf, n_folds=5):
    if len(Y) != X.shape[0]:
        print("Label size does not match")
        #return
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
    
    p_corrects = []
    for train, test in kf.split(X):
        x_train = X[train]
        x_test = X[test]
        
        y_train = Y[train]
        y_test = Y[test]
        
        start = time.time()
        clf.fit(x_train, y_train)
        end = time.time()
        print("Classification took {:.1f} seconds".format(end-start))
        
        predY = clf.predict(x_test).round()
        p_corrects.append(np.count_nonzero(predY == y_test) / float(len(y_test)))
        print('\tTest Fold accuracy: {:.3f}'.format(p_corrects[-1]))
        
        predY = clf.predict(x_train).round()
        train_correct = np.count_nonzero(predY == y_train) / float(len(y_train))
        print('\tTrain Fold accuracy: {:.3f}'.format(train_correct))
        
    print("Mean correct across {} folds: {:.3f}".format(n_folds, np.mean(p_corrects)))

Y = (cleaned.state == 'successful').values

print("Baseline accuracy is {:.3f}".format( 1 - (float(sum(Y)) / len(Y))))
# Out:
# Baseline accuracy is 0.520

# %%
from sklearn.linear_model import LogisticRegression
run_classifier(scaled_sim, Y, LinearSVC())
run_classifier(scaled_sim,  Y, LogisticRegression())
# Out:
# Classification took 3.5 seconds
# 	Test Fold accuracy: 0.632
# 	Train Fold accuracy: 0.632
# Classification took 3.5 seconds
# 	Test Fold accuracy: 0.634
# 	Train Fold accuracy: 0.631
# Classification took 3.5 seconds
# 	Test Fold accuracy: 0.630
# 	Train Fold accuracy: 0.632
# Classification took 3.5 seconds
# 	Test Fold accuracy: 0.633
# 	Train Fold accuracy: 0.631
# Classification took 3.6 seconds
# 	Test Fold accuracy: 0.629
# 	Train Fold accuracy: 0.632
# Mean correct across 5 folds: 0.631
# Classification took 0.1 seconds
# 	Test Fold accuracy: 0.633
# 	Train Fold accuracy: 0.631
# Classification took 0.1 seconds
# 	Test Fold accuracy: 0.634
# 	Train Fold accuracy: 0.631
# Classification took 0.1 seconds
# 	Test Fold accuracy: 0.630
# 	Train Fold accuracy: 0.632
# Classification took 0.1 seconds
# 	Test Fold accuracy: 0.634
# 	Train Fold accuracy: 0.631
# Classification took 0.1 seconds
# 	Test Fold accuracy: 0.628
# 	Train Fold accuracy: 0.633
# Mean correct across 5 folds: 0.632

# %%
run_classifier(sim_and_numerical_features, Y, LinearSVC())
# Out:
# Classification took 4.7 seconds
# 	Test Fold accuracy: 0.733
# 	Train Fold accuracy: 0.737
# Classification took 4.8 seconds
# 	Test Fold accuracy: 0.743
# 	Train Fold accuracy: 0.734
# Classification took 4.7 seconds
# 	Test Fold accuracy: 0.732
# 	Train Fold accuracy: 0.737
# Classification took 4.8 seconds
# 	Test Fold accuracy: 0.734
# 	Train Fold accuracy: 0.737
# Classification took 4.8 seconds
# 	Test Fold accuracy: 0.732
# 	Train Fold accuracy: 0.737
# Mean correct across 5 folds: 0.735

# %%
run_classifier(scaled_text_and_numerical, Y, LogisticRegression())
# Out:
# Classification took 16.3 seconds
# 	Test Fold accuracy: 0.733
# 	Train Fold accuracy: 0.740
# Classification took 13.3 seconds
# 	Test Fold accuracy: 0.740
# 	Train Fold accuracy: 0.738
# Classification took 15.3 seconds
# 	Test Fold accuracy: 0.733
# 	Train Fold accuracy: 0.739
# Classification took 15.6 seconds
# 	Test Fold accuracy: 0.735
# 	Train Fold accuracy: 0.739
# Classification took 13.2 seconds
# 	Test Fold accuracy: 0.736
# 	Train Fold accuracy: 0.739
# Mean correct across 5 folds: 0.735

# %%
run_classifier(sim_text_and_numerical, Y, LogisticRegression())
# Out:
# Classification took 14.2 seconds
# 	Test Fold accuracy: 0.737
# 	Train Fold accuracy: 0.744
# Classification took 13.4 seconds
# 	Test Fold accuracy: 0.745
# 	Train Fold accuracy: 0.742
# Classification took 15.1 seconds
# 	Test Fold accuracy: 0.737
# 	Train Fold accuracy: 0.743
# Classification took 13.9 seconds
# 	Test Fold accuracy: 0.740
# 	Train Fold accuracy: 0.743
# Classification took 17.1 seconds
# 	Test Fold accuracy: 0.737
# 	Train Fold accuracy: 0.743
# Mean correct across 5 folds: 0.739

# %%
run_classifier(sim_and_numerical_features, Y, LinearSVC())
# Out:
# Classification took 6.6 seconds
# 	Fold accuracy: 0.643
# Classification took 6.9 seconds
# 	Fold accuracy: 0.650
# Classification took 6.8 seconds
# 	Fold accuracy: 0.641
# Classification took 6.8 seconds
# 	Fold accuracy: 0.644
# Classification took 6.7 seconds
# 	Fold accuracy: 0.648
# Mean correct across 5 folds: 0.645

# %%
run_classifier(scaled_numerical_features, Y, LogisticRegression(max_iter=1000, C=0.1, tol=1e-6))
# Out:
# Classification took 7.0 seconds
# 	Test Fold accuracy: 0.719
# 	Train Fold accuracy: 0.726
# Classification took 6.7 seconds
# 	Test Fold accuracy: 0.717
# 	Train Fold accuracy: 0.726
# Classification took 6.4 seconds
# 	Test Fold accuracy: 0.724
# 	Train Fold accuracy: 0.724
# Classification took 6.4 seconds
# 	Test Fold accuracy: 0.725
# 	Train Fold accuracy: 0.725
# Classification took 6.5 seconds
# 	Test Fold accuracy: 0.728
# 	Train Fold accuracy: 0.723
# Mean correct across 5 folds: 0.723

# %%
run_classifier(sim_text_and_numerical, Y, LinearSVC())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-206-cb0ee5722c8a> in <module>()
# ----> 1 run_classifier(sim_text_and_numerical, Y, LinearSVC())
#
# <ipython-input-28-7c1f66775f8e> in inner(*args, **kwargs)
#       4     def inner(*args, **kwargs):
#       5         try:
# ----> 6             return fn(*args, **kwargs)
#       7         except Exception:
#       8             print(traceback.format_exc())
#
# <ipython-input-185-68e0472ec040> in run_classifier(X, Y, clf, n_folds)
#      27
#      28         start = time.time()
# ---> 29         clf.fit(x_train, y_train)
#      30         end = time.time()
#      31         print("Classification took {:.1f} seconds".format(end-start))
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/svm/classes.py in fit(self, X, y, sample_weight)
#     233             self.class_weight, self.penalty, self.dual, self.verbose,
#     234             self.max_iter, self.tol, self.random_state, self.multi_class,
# --> 235             self.loss, sample_weight=sample_weight)
#     236
#     237         if self.multi_class == "crammer_singer" and len(self.classes_) == 2:
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/svm/base.py in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     888         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     889         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
# --> 890         epsilon, sample_weight)
#     891     # Regarding rnd.randint(..) in the above signature:
#     892     # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#
# KeyboardInterrupt:

# %%
from sklearn.linear_model import SGDClassifier
run_classifier(sim_and_scaled_numerical, Y, SGDClassifier())
# Out:
# /Users/sahithyaprakash/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# Classification took 0.1 seconds
# 	Test Fold accuracy: 0.677
# 	Train Fold accuracy: 0.679
# Classification took 0.1 seconds
# 	Test Fold accuracy: 0.685
# 	Train Fold accuracy: 0.694
# Classification took 0.1 seconds
# 	Test Fold accuracy: 0.641
# 	Train Fold accuracy: 0.641
# Classification took 0.2 seconds
# 	Test Fold accuracy: 0.665
# 	Train Fold accuracy: 0.669
# Classification took 0.1 seconds
# 	Test Fold accuracy: 0.680
# 	Train Fold accuracy: 0.679
# Mean correct across 5 folds: 0.670

# %%
run_classifier(scaled_sim.reshape(-1, 1), Y, LogisticRegression())
# Out:
# Classification took 0.0 seconds
# 	Test Fold accuracy: 0.545
# 	Train Fold accuracy: 0.540
# Classification took 0.0 seconds
# 	Test Fold accuracy: 0.542
# 	Train Fold accuracy: 0.541
# Classification took 0.0 seconds
# 	Test Fold accuracy: 0.535
# 	Train Fold accuracy: 0.542
# Classification took 0.0 seconds
# 	Test Fold accuracy: 0.545
# 	Train Fold accuracy: 0.540
# Classification took 0.0 seconds
# 	Test Fold accuracy: 0.539
# 	Train Fold accuracy: 0.541
# Mean correct across 5 folds: 0.541

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
run_classifier(scaled_text_and_numerical, Y, LogisticRegression())
# Out:
# Classification took 12.2 seconds
# 	Test Fold accuracy: 0.509
# 	Train Fold accuracy: 0.533
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-198-f60ecb2c731d> in <module>()
#       1 from sklearn.ensemble import GradientBoostingClassifier
#       2 from sklearn.ensemble import AdaBoostClassifier
# ----> 3 run_classifier(scaled_text_and_numerical, Y, LogisticRegression())
#
# <ipython-input-28-7c1f66775f8e> in inner(*args, **kwargs)
#       4     def inner(*args, **kwargs):
#       5         try:
# ----> 6             return fn(*args, **kwargs)
#       7         except Exception:
#       8             print(traceback.format_exc())
#
# <ipython-input-185-68e0472ec040> in run_classifier(X, Y, clf, n_folds)
#      27
#      28         start = time.time()
# ---> 29         clf.fit(x_train, y_train)
#      30         end = time.time()
#      31         print("Classification took {:.1f} seconds".format(end-start))
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1231                 self.class_weight, self.penalty, self.dual, self.verbose,
#    1232                 self.max_iter, self.tol, self.random_state,
# -> 1233                 sample_weight=sample_weight)
#    1234             self.n_iter_ = np.array([n_iter_])
#    1235             return self
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/svm/base.py in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#     888         X, y_ind, sp.isspmatrix(X), solver_type, tol, bias, C,
#     889         class_weight_, max_iter, rnd.randint(np.iinfo('i').max),
# --> 890         epsilon, sample_weight)
#     891     # Regarding rnd.randint(..) in the above signature:
#     892     # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#
# KeyboardInterrupt:

# %%
from sklearn.linear_model import LogisticRegression
run_classifier(text_and_scaled_numerical, Y, LogisticRegression())
# Out:
# Classification took 34.9 seconds
# 	Test Fold accuracy: 0.742
# 	Train Fold accuracy: 0.744
# Classification took 31.6 seconds
# 	Test Fold accuracy: 0.737
# 	Train Fold accuracy: 0.745
# Classification took 36.9 seconds
# 	Test Fold accuracy: 0.738
# 	Train Fold accuracy: 0.745
# Classification took 39.7 seconds
# 	Test Fold accuracy: 0.746
# 	Train Fold accuracy: 0.743
# Classification took 33.8 seconds
# 	Test Fold accuracy: 0.741
# 	Train Fold accuracy: 0.745
# Mean correct across 5 folds: 0.743

# %%
@cannot_crash
def predicted_goal_percent_comparison(clf):

    clf.fit(all_features, Y)
    pred = clf.predict(all_features)

    plt.figure()

    pred_success = cleaned[pred == 1]
    pred_failures = cleaned[pred == 0]
    goal_percent_comparison(pred_success, pred_failures)
    plt.legend(['predicted successes', 'predicted failures'])

    mispred_success = cleaned[(pred == 0) & (cleaned.state == 'successful') ]
    mispred_fail = cleaned[(pred == 1) & (cleaned.state != 'successful') ]
    plt.figure()
    goal_percent_comparison(mispred_success, mispred_fail)
    plt.legend(['mispredicted successes', 'mispredicted failures'])
    
    return cleaned[mispred_success | mispred_fail]

predicted_goal_percent_comparison()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Traceback (most recent call last):
#   File "<ipython-input-10-7c1f66775f8e>", line 6, in inner
#     return fn(*args, **kwargs)
#   File "<ipython-input-35-bb68d17deba5>", line 21, in predicted_goal_percent_comparison
#     return cleaned[mispred_success | mispred_fail]
#   File "/Users/iped/miniconda2/envs/py3/lib/python3.6/site-packages/pandas/core/frame.py", line 2135, in __getitem__
#     return self._getitem_frame(key)
#   File "/Users/iped/miniconda2/envs/py3/lib/python3.6/site-packages/pandas/core/frame.py", line 2218, in _getitem_frame
#     raise ValueError('Must pass DataFrame with boolean values only')
# ValueError: Must pass DataFrame with boolean values only

# %%
# %matplotlib notebook
@cannot_crash
def show_created_at_hist():
    plt.hist(cleaned.created_at, 50)
    plt.show()
    print(cleaned.created_at.min())
    print(cleaned.created_at.max())

show_created_at_hist()
# Out:
# <img src="data:image/png;base64,..." width="640">
# 2009-04-21 17:35:35
# 2015-05-22 20:06:40

# %%
import torch
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from pprint import pprint
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable

class MyDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, x_train, y_train, x_test, y_test):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.len = x_train.shape[0]
        self.x_data = torch.from_numpy(x_train).float()
        self.y_data = torch.from_numpy(y_train).long()
        
        self.x_test = torch.from_numpy(x_test).float()
        self.y_test = torch.from_numpy(y_test).long()

    def __len__(self):

        return self.len

    def __getitem__(self, idx):

        return self.x_data[idx], self.y_data[idx]    
    
class FFNet(nn.Module):
    def __init__(self, n_features, params):
        super(FFNet, self).__init__()
        layer_size = params.get('hidden', 256)
        
        self.fc1 = nn.Linear(int(n_features), layer_size)
        
        self.fc_deep = []
        for i in range(params.get('depth', 1) - 1):
            next_layer_size = int(layer_size/params.get('reduction', 2))
            self.fc_deep.append(nn.Linear(layer_size, next_layer_size))
            layer_size = next_layer_size
        
        self.fc3 = nn.Linear(layer_size, 2)

    def forward(self, x):
        out = x.view(x.shape[0], -1)
        out = F.sigmoid(self.fc1(out))
        for fc in self.fc_deep:
            out = F.sigmoid(fc(out))
        out = F.sigmoid(self.fc3(out))
        
        return out

def nn_classify(dataset, params):
    
    print("Starting classifier")
    net = FFNet(dataset.x_data.shape[1], params)
    
    train_loader = DataLoader(
        dataset=dataset,
        batch_size = params.get('batch_size', 20),
        shuffle = True
    )
    # Specify the loss function
    criterion = nn.CrossEntropyLoss()

    # Specify the optimizer
    optimizer = optim.SGD(net.parameters(),
                          lr=params.get('learning_rate', .01), 
                          momentum=params.get('momentum', .9))    
    
    max_epochs = params.get('epochs', 20)

    for epoch in range(max_epochs):
        print("Epoch %d" % epoch)
        for i, data in enumerate(train_loader, 0):
            
            inputs, labels = data
            inputs, labels = Variable(inputs), Variable(labels)
            optimizer.zero_grad()
            
            y_pred = net(inputs)
            
            loss = criterion(y_pred, torch.max(labels,1)[0])
            
            if (i % 1000) == 1:
                print("Loss: ", loss.data[0])
            
            
            loss.backward()
            
            optimizer.step()

        test_data = Variable(dataset.x_test)
        test_labels = Variable(dataset.y_test).data.numpy()

        outputs = net(test_data)
        _, predicted = torch.max(outputs.data, 1)
        total = test_labels.shape[0]
        correct = 0
        unique_predictions = set()
        for i, label in enumerate(test_labels):
            if predicted[i] == label:
                correct += 1
            unique_predictions.add(predicted[i])
        print(unique_predictions)

        epoch_accuracy = float(correct) / float(total)

        print("epoch test accuracy: ", epoch_accuracy)

    
    test_data = Variable(dataset.x_test)
    test_labels = Variable(dataset.y_test)
    
    outputs = net(test_data)
    _, predicted = torch.max(outputs.data, 1)
    total = test_labels.size(0)
    correct = (predicted == dataset.y_test).sum()

    final_accuracy = float(correct) / float(total)
    
    print("Final test accuracy: ", final_accuracy)
    
    return final_accuracy

# %%
from sklearn.model_selection import KFold

def run_nn(X, Y, n_folds=5, **params):
    print("Creating kfold")
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=42)
    
    p_corrects = []
    print("Folding")
    for train, test in kf.split(X):
        x_train = X[train,:]
        x_test = X[test,:]
        
        y_train = Y[train]
        y_test = Y[test]
        
        print ("Creating dataset")
        dataset = MyDataset(x_train, y_train, x_test, y_test)
        
        p_corrects.append(nn_classify(dataset, params))
        
    return p_corrects

# %%
import random
def sample_equally(X, Y):
    n1 = np.count_nonzero(Y)
    n0 = len(Y) - n1
    
    if n0 > n1:
        zs = np.arange(len(Y))[(Y==0)]
        z_inds = random.sample(range(n0),n0 - n1)
        rm_inds = zs[z_inds]
    elif n1 > n0:
        nzs = (Y==1).nonzero()
        rm_inds = nzs[np.array(random.sample(range(n1), n1 - n0))]
        
    X = np.delete(X, rm_inds, axis=0)
    return X, np.delete(Y, rm_inds)

# %%
Y_nn = np.zeros(shape=(len(cleaned),1))
Y_nn[cleaned.state == 'successful'] = 1
print(np.count_nonzero(Y_nn), len(Y_nn) - np.count_nonzero(Y_nn))
# Out:
# 37434 40502

# %%
s_x, s_y = sample_equally(sim_text_and_numerical, Y)
print(s_x.shape, s_y.astype(int).reshape(-1, 1))
# Out:
# (74868, 378) [[1]
#  [0]
#  [1]
#  ...
#  [0]
#  [0]
#  [0]]

# %%
run_nn(s_x, s_y.astype(int).reshape(-1, 1))
# Out:
# Creating kfold
# Folding
# Creating dataset
# Starting classifier
# Epoch 0
# Loss:  0.7158806324005127
# Loss:  0.6513263583183289
# Loss:  0.5737229585647583
# {0, 1}
# epoch test accuracy:  0.7323360491518632
# Epoch 1
# Loss:  0.589099109172821
# Loss:  0.5837602019309998
# Loss:  0.5869137048721313
# {0, 1}
# epoch test accuracy:  0.7355416054494457
# Epoch 2
# Loss:  0.4490327835083008
# Loss:  0.5551131963729858
# Loss:  0.5873366594314575
# {0, 1}
# epoch test accuracy:  0.7354080406037131
# Epoch 3
# Loss:  0.4629541039466858
# Loss:  0.4825231432914734
# Loss:  0.6210789084434509
# {0, 1}
# epoch test accuracy:  0.7365433417924402
# Epoch 4
# Loss:  0.42301613092422485
# Loss:  0.6352623105049133
# Loss:  0.5125936269760132
# {0, 1}
# epoch test accuracy:  0.7368104714839054
# Epoch 5
# Loss:  0.5675520896911621
# Loss:  0.5951464176177979
# Loss:  0.43261733651161194
# {0, 1}
# epoch test accuracy:  0.7360758648323761
# Epoch 6
# Loss:  0.48583632707595825
# Loss:  0.642297625541687
# Loss:  0.5143715739250183
# {0, 1}
# epoch test accuracy:  0.7339388273006545
# Epoch 7
# Loss:  0.4855779707431793
# Loss:  0.5744756460189819
# Loss:  0.5724624395370483
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-273-c85399ab631f> in <module>()
# ----> 1 run_nn(s_x, s_y.astype(int).reshape(-1, 1))
#
# <ipython-input-210-ca9c2620b80a> in run_nn(X, Y, n_folds, **params)
#      17         dataset = MyDataset(x_train, y_train, x_test, y_test)
#      18
# ---> 19         p_corrects.append(nn_classify(dataset, params))
#      20
#      21     return p_corrects
#
# <ipython-input-209-11dd973662dc> in nn_classify(dataset, params)
#      94
#      95
# ---> 96             loss.backward()
#      97
#      98             optimizer.step()
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/autograd/variable.py in backward(self, gradient, retain_graph, create_graph, retain_variables)
#     165                 Variable.
#     166         """
# --> 167         torch.autograd.backward(self, gradient, retain_graph, create_graph, retain_variables)
#     168
#     169     def register_hook(self, hook):
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(variables, grad_variables, retain_graph, create_graph, retain_variables)
#      97
#      98     Variable._execution_engine.run_backward(
# ---> 99         variables, grad_variables, retain_graph)
#     100
#     101
#
# KeyboardInterrupt:

# %%
run_nn(text_and_scaled_numerical, Y, learning_rate=.001, hidden=1024, batch_size=10, epochs=5)
# Out:
# Creating kfold
# Folding
# Creating dataset
# Starting classifier
# Epoch 0
# Loss:  0.6981838941574097
# Loss:  0.639136552810669
# Loss:  0.7277930974960327
# Loss:  0.6587914228439331
# Loss:  0.6729372143745422
# Loss:  0.5660527944564819
# Loss:  0.6231781840324402
# Loss:  0.6170529723167419
# {0, 1}
# epoch test accuracy:  0.731442032980803
# Epoch 1
# Loss:  0.5149049758911133
# Loss:  0.5165958404541016
# Loss:  0.6978884339332581
# Loss:  0.6515159606933594
# Loss:  0.5244196653366089
# Loss:  0.5871027708053589
# Loss:  0.4464356303215027
# Loss:  0.4894797205924988
# {0, 1}
# epoch test accuracy:  0.7380582426946017
# Epoch 2
# Loss:  0.6546247005462646
# Loss:  0.5694209337234497
# Loss:  0.597527027130127
# Loss:  0.45643386244773865
# Loss:  0.5758172273635864
# Loss:  0.4131811261177063
# Loss:  0.4658459722995758
# Loss:  0.6826313138008118
# {0, 1}
# epoch test accuracy:  0.7378577514911533
# Epoch 3
# Loss:  0.5184512138366699
# Loss:  0.5309258699417114
# Loss:  0.58314448595047
# Loss:  0.6129629015922546
# Loss:  0.5087636709213257
# Loss:  0.5642541646957397
# Loss:  0.5685954093933105
# Loss:  0.5512081980705261
# {0, 1}
# epoch test accuracy:  0.7342990326299433
# Epoch 4
# Loss:  0.43382492661476135
# Loss:  0.445880264043808
# Loss:  0.6814700961112976
# Loss:  0.5475090742111206
# Loss:  0.4983927607536316
# Loss:  0.46998438239097595
# Loss:  0.49247971177101135
# Loss:  0.8753131628036499
# {0, 1}
# epoch test accuracy:  0.7393113127161546
# Final test accuracy:  10458.53661470603
# Creating dataset
# Starting classifier
# Epoch 0
# Loss:  0.6721567511558533
# Loss:  0.6067511439323425
# Loss:  0.659562349319458
# Loss:  0.6563001871109009
# Loss:  0.6519285440444946
# Loss:  0.6924887895584106
# Loss:  0.6793548464775085
# Loss:  0.5189356207847595
# {0, 1}
# epoch test accuracy:  0.7275825773144203
# Epoch 1
# Loss:  0.4349171221256256
# Loss:  0.45564526319503784
# Loss:  0.5362558960914612
# Loss:  0.5110234022140503
# Loss:  0.6216219663619995
# Loss:  0.5483950972557068
# Loss:  0.4215734899044037
# Loss:  0.6223248243331909
# {0, 1}
# epoch test accuracy:  0.7344995238333918
# Epoch 2
# Loss:  0.6299282312393188
# Loss:  0.6297205090522766
# Loss:  0.5936884880065918
# Loss:  0.5061619877815247
# Loss:  0.5648188591003418
# Loss:  0.6926449537277222
# Loss:  0.5428109765052795
# Loss:  0.45538216829299927
# {0, 1}
# epoch test accuracy:  0.7378577514911533
# Epoch 3
# Loss:  0.5542246103286743
# Loss:  0.5649649500846863
# Loss:  0.5547014474868774
# Loss:  0.46351146697998047
# Loss:  0.5986555218696594
# Loss:  0.700309157371521
# Loss:  0.573704719543457
# Loss:  0.511275589466095
# {0, 1}
# epoch test accuracy:  0.7370557866773595
# Epoch 4
# Loss:  0.5754576921463013
# Loss:  0.4830029606819153
# Loss:  0.5356712341308594
# Loss:  0.43807893991470337
# Loss:  0.5835424661636353
# Loss:  0.6642355918884277
# Loss:  0.4731336534023285
# Loss:  0.6034971475601196
# {0, 1}
# epoch test accuracy:  0.7392611899152924
# Final test accuracy:  10399.28138940404
# Creating dataset
# Starting classifier
# Epoch 0
# Loss:  0.7137176990509033
# Loss:  0.6790202856063843
# Loss:  0.6594743132591248
# Loss:  0.6390725374221802
# Loss:  0.5971490144729614
# Loss:  0.6736707091331482
# Loss:  0.5865718126296997
# Loss:  0.8757109642028809
# {0, 1}
# epoch test accuracy:  0.7275324545135582
# Epoch 1
# Loss:  0.6568319797515869
# Loss:  0.6294161081314087
# Loss:  0.5105655789375305
# Loss:  0.4734111726284027
# Loss:  0.5007057785987854
# Loss:  0.47206321358680725
# Loss:  0.5223180055618286
# Loss:  0.6621434092521667
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-117-bc0a7991e20a> in <module>()
# ----> 1 run_nn(text_and_scaled_numerical, Y, learning_rate=.001, hidden=1024, batch_size=10, epochs=5)
#
# <ipython-input-112-ca9c2620b80a> in run_nn(X, Y, n_folds, **params)
#      17         dataset = MyDataset(x_train, y_train, x_test, y_test)
#      18
# ---> 19         p_corrects.append(nn_classify(dataset, params))
#      20
#      21     return p_corrects
#
# <ipython-input-108-65591202451d> in nn_classify(dataset, params)
#      90         test_labels = Variable(dataset.y_test).data.numpy()
#      91
# ---> 92         outputs = net(test_data)
#      93         _, predicted = torch.max(outputs.data, 1)
#      94         total = test_labels.shape[0]
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# <ipython-input-108-65591202451d> in forward(self, x)
#      42     def forward(self, x):
#      43         out = x.view(x.shape[0], -1)
# ---> 44         out = F.sigmoid(self.fc1(out))
#      45         out = F.sigmoid(self.fc3(out))
#      46
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/functional.py in sigmoid(input)
#     815     See :class:`~torch.nn.Sigmoid` for more details.
#     816     """
# --> 817     return input.sigmoid()
#     818
#     819
#
# KeyboardInterrupt:

# %%
run_nn(text_and_scaled_numerical, Y, learning_rate=.01, hidden=256, reduction=2, depth=2, epochs=10)
# Out:
# Creating kfold
# Folding
# Creating dataset
# Starting classifier
# Epoch 0
# Loss:  0.6901338696479797
# Loss:  0.7038262486457825
# Loss:  0.6982943415641785
# Loss:  0.6847082376480103
# {0, 1}
# epoch test accuracy:  0.639867675805724
# Epoch 1
# Loss:  0.6676581501960754
# Loss:  0.6404693722724915
# Loss:  0.5923784375190735
# Loss:  0.5461252927780151
# {0, 1}
# epoch test accuracy:  0.7319933837902862
# Epoch 2
# Loss:  0.5485716462135315
# Loss:  0.5210773348808289
# Loss:  0.5621083378791809
# Loss:  0.5957036018371582
# {0, 1}
# epoch test accuracy:  0.7385093479023608
# Epoch 3
# Loss:  0.5669731497764587
# Loss:  0.5314530730247498
# Loss:  0.5673077702522278
# Loss:  0.5819646716117859
# {0, 1}
# epoch test accuracy:  0.7379579970928776
# Epoch 4
# Loss:  0.4859185814857483
# Loss:  0.5474780201911926
# Loss:  0.6068885326385498
# Loss:  0.46962395310401917
# {0, 1}
# epoch test accuracy:  0.7387599619066714
# Epoch 5
# Loss:  0.5317854881286621
# Loss:  0.587786078453064
# Loss:  0.3982817530632019
# Loss:  0.7113136053085327
# {0, 1}
# epoch test accuracy:  0.7372562778808079
# Epoch 6
# Loss:  0.5996938943862915
# Loss:  0.5244380235671997
# Loss:  0.5954167246818542
# Loss:  0.5888307094573975
# {0, 1}
# epoch test accuracy:  0.7393113127161546
# Epoch 7
# Loss:  0.6037671566009521
# Loss:  0.4986483156681061
# Loss:  0.4457503855228424
# Loss:  0.6994146704673767
# {0, 1}
# epoch test accuracy:  0.7372061550799459
# Epoch 8
# Loss:  0.5686686038970947
# Loss:  0.6895476579666138
# Loss:  0.5293334722518921
# Loss:  0.5919758081436157
# {0, 1}
# epoch test accuracy:  0.7386597163049471
# Epoch 9
# Loss:  0.5263537168502808
# Loss:  0.5695676207542419
# Loss:  0.519305944442749
# Loss:  0.48468953371047974
# {0, 1}
# epoch test accuracy:  0.7365044358678763
# Final test accuracy:  10552.746629241641
# Creating dataset
# Starting classifier
# Epoch 0
# Loss:  0.6888059377670288
# Loss:  0.7280986309051514
# Loss:  0.6876700520515442
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-126-c913e279a55e> in <module>()
# ----> 1 run_nn(text_and_scaled_numerical, Y, learning_rate=.01, hidden=256, reduction=2, depth=2, epochs=10)
#
# <ipython-input-121-ca9c2620b80a> in run_nn(X, Y, n_folds, **params)
#      17         dataset = MyDataset(x_train, y_train, x_test, y_test)
#      18
# ---> 19         p_corrects.append(nn_classify(dataset, params))
#      20
#      21     return p_corrects
#
# <ipython-input-120-11dd973662dc> in nn_classify(dataset, params)
#      94
#      95
# ---> 96             loss.backward()
#      97
#      98             optimizer.step()
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/autograd/variable.py in backward(self, gradient, retain_graph, create_graph, retain_variables)
#     165                 Variable.
#     166         """
# --> 167         torch.autograd.backward(self, gradient, retain_graph, create_graph, retain_variables)
#     168
#     169     def register_hook(self, hook):
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(variables, grad_variables, retain_graph, create_graph, retain_variables)
#      97
#      98     Variable._execution_engine.run_backward(
# ---> 99         variables, grad_variables, retain_graph)
#     100
#     101
#
# KeyboardInterrupt:

# %%
run_nn(scaled_svd, Y, learning_rate=.01, hidden=256, epochs=10)
# Out:
# Creating kfold
# Folding
# Creating dataset
# Starting classifier
# Epoch 0
# Loss:  0.6875384449958801
# Loss:  0.6418712139129639
# Loss:  0.6203967332839966
# Loss:  0.6492863893508911
# {0, 1}
# epoch test accuracy:  0.6355571149315824
# Epoch 1
# Loss:  0.6106522679328918
# Loss:  0.5900206565856934
# Loss:  0.6249173283576965
# Loss:  0.6196650266647339
# {0, 1}
# epoch test accuracy:  0.6335020800962358
# Epoch 2
# Loss:  0.6345769166946411
# Loss:  0.6641703844070435
# Loss:  0.627580463886261
# Loss:  0.6810747981071472
# {0, 1}
# epoch test accuracy:  0.6389153425893439
# Epoch 3
# Loss:  0.6498422026634216
# Loss:  0.6084374189376831
# Loss:  0.6143381595611572
# Loss:  0.5888262987136841
# {0, 1}
# epoch test accuracy:  0.6417723422384843
# Epoch 4
# Loss:  0.6722779870033264
# Loss:  0.6459130048751831
# Loss:  0.6923409700393677
# Loss:  0.7293860912322998
# {0, 1}
# epoch test accuracy:  0.6401182898100346
# Epoch 5
# Loss:  0.6698841452598572
# Loss:  0.637536346912384
# Loss:  0.5528436303138733
# Loss:  0.6826015710830688
# {0, 1}
# epoch test accuracy:  0.6394666933988271
# Epoch 6
# Loss:  0.6438542604446411
# Loss:  0.510182797908783
# Loss:  0.6082876324653625
# Loss:  0.6089602708816528
# {0, 1}
# epoch test accuracy:  0.6429251666583129
# Epoch 7
# Loss:  0.5645903944969177
# Loss:  0.6788821816444397
# Loss:  0.6133721470832825
# Loss:  0.6855959296226501
# {0, 1}
# epoch test accuracy:  0.6404190266152072
# Epoch 8
# Loss:  0.6090317964553833
# Loss:  0.6827107071876526
# Loss:  0.5632003545761108
# Loss:  0.5368083119392395
# {0, 1}
# epoch test accuracy:  0.6408701318229663
# Epoch 9
# Loss:  0.5426799058914185
# Loss:  0.501911997795105
# Loss:  0.6508419513702393
# Loss:  0.6352666616439819
# {0, 1}
# epoch test accuracy:  0.6402686582126209
# Final test accuracy:  10326.474362187359
# Creating dataset
# Starting classifier
# Epoch 0
# Loss:  0.6829168796539307
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-132-562cd0fff524> in <module>()
# ----> 1 run_nn(scaled_svd, Y, learning_rate=.01, hidden=256, epochs=10)
#
# <ipython-input-121-ca9c2620b80a> in run_nn(X, Y, n_folds, **params)
#      17         dataset = MyDataset(x_train, y_train, x_test, y_test)
#      18
# ---> 19         p_corrects.append(nn_classify(dataset, params))
#      20
#      21     return p_corrects
#
# <ipython-input-120-11dd973662dc> in nn_classify(dataset, params)
#      86             optimizer.zero_grad()
#      87
# ---> 88             y_pred = net(inputs)
#      89
#      90             loss = criterion(y_pred, torch.max(labels,1)[0])
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# <ipython-input-120-11dd973662dc> in forward(self, x)
#      51     def forward(self, x):
#      52         out = x.view(x.shape[0], -1)
# ---> 53         out = F.sigmoid(self.fc1(out))
#      54         for fc in self.fc_deep:
#      55             out = F.sigmoid(fc(out))
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      53
#      54     def forward(self, input):
# ---> 55         return F.linear(input, self.weight, self.bias)
#      56
#      57     def __repr__(self):
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#     833     if input.dim() == 2 and bias is not None:
#     834         # fused op is marginally faster
# --> 835         return torch.addmm(bias, input, weight.t())
#     836
#     837     output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
run_nn(scaled_svd, Y, learning_rate=.01, hidden=512, depth=2, reduction=4, epochs=10)
# Out:
# Creating kfold
# Folding
# Creating dataset
# Starting classifier
# Epoch 0
# Loss:  0.6995352506637573
# Loss:  0.6888347268104553
# Loss:  0.6585656404495239
# Loss:  0.6868313550949097
# {0}
# epoch test accuracy:  0.5700967370056639
# Epoch 1
# Loss:  0.6663484573364258
# Loss:  0.7015472054481506
# Loss:  0.701919674873352
# Loss:  0.7282036542892456
# {0, 1}
# epoch test accuracy:  0.5709488246203198
# Epoch 2
# Loss:  0.6706143021583557
# Loss:  0.6558045148849487
# Loss:  0.6907379627227783
# Loss:  0.687226414680481
# {0, 1}
# epoch test accuracy:  0.6551050072678061
# Epoch 3
# Loss:  0.6809672117233276
# Loss:  0.6095945239067078
# Loss:  0.6754971742630005
# Loss:  0.5183638334274292
# {0, 1}
# epoch test accuracy:  0.6565585684928074
# Epoch 4
# Loss:  0.6741012334823608
# Loss:  0.536851704120636
# Loss:  0.6050442457199097
# Loss:  0.4947487413883209
# {0, 1}
# epoch test accuracy:  0.6528494812290111
# Epoch 5
# Loss:  0.5889533758163452
# Loss:  0.6827093362808228
# Loss:  0.7638753652572632
# Loss:  0.6130024194717407
# {0, 1}
# epoch test accuracy:  0.6569595508997043
# Epoch 6
# Loss:  0.6307799816131592
# Loss:  0.621536374092102
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-143-32e98a7764fe> in <module>()
# ----> 1 run_nn(scaled_svd, Y, learning_rate=.01, hidden=512, depth=2, reduction=4, epochs=10)
#
# <ipython-input-121-ca9c2620b80a> in run_nn(X, Y, n_folds, **params)
#      17         dataset = MyDataset(x_train, y_train, x_test, y_test)
#      18
# ---> 19         p_corrects.append(nn_classify(dataset, params))
#      20
#      21     return p_corrects
#
# <ipython-input-120-11dd973662dc> in nn_classify(dataset, params)
#      86             optimizer.zero_grad()
#      87
# ---> 88             y_pred = net(inputs)
#      89
#      90             loss = criterion(y_pred, torch.max(labels,1)[0])
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# <ipython-input-120-11dd973662dc> in forward(self, x)
#      51     def forward(self, x):
#      52         out = x.view(x.shape[0], -1)
# ---> 53         out = F.sigmoid(self.fc1(out))
#      54         for fc in self.fc_deep:
#      55             out = F.sigmoid(fc(out))
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      53
#      54     def forward(self, input):
# ---> 55         return F.linear(input, self.weight, self.bias)
#      56
#      57     def __repr__(self):
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#     833     if input.dim() == 2 and bias is not None:
#     834         # fused op is marginally faster
# --> 835         return torch.addmm(bias, input, weight.t())
#     836
#     837     output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
max_size = max(max(r for r in row) for row in rows)
X_torch = np.zeros(shape=(len(rows), max_size + 2))
for i, row in enumerate(rows):
    X_torch[i, row] = 1
    X_torch[i, -1] = np.log(cleaned['goal'].iloc[i])

# %%
run_nn(X_torch, Y.astype(np.int32))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-39993228329a> in <module>()
# ----> 1 run_nn(X_torch, Y.astype(np.int32))
#
# NameError: name 'Y' is not defined

# %%
from sklearn.feature_extraction.text import HashingVectorizer
# list of text documents
# create the transform
hash_size = 2048
vectorizer = HashingVectorizer(n_features=hash_size)
# encode document
X_torch = np.zeros(shape=(len(succ_fail_only), hash_size * 2))
print("Vectorizing")
descs = vectorizer.transform(succ_fail_only['desc'])
X_torch[:,:hash_size] = descs.toarray()

print("Vectorizing")
vectorizer = HashingVectorizer(n_features=hash_size)
names = vectorizer.transform(succ_fail_only['name'])
print("Iterating")
X_torch[:,hash_size:] = names.toarray()
# summarize encoded vector

Y_torch = np.zeros(shape=(len(succ_fail_only),))
Y_torch[succ_fail_only.state == 'successful'] = 1
#Y_torch[cleaned.state == 'canceled'] = 2
# Out:
# Vectorizing
# Vectorizing
# Iterating

# %%
X_torch[100:200,100:200][X_torch[100:200,100:200].nonzero()]
# Out:
# array([-0.19245009, -0.57735027,  0.2       ,  0.2       , -0.2       ,
#        -0.36514837,  0.18257419, -0.18257419, -0.64051262, -0.15811388,
#        -0.63245553, -0.39223227, -0.39223227, -0.22941573, -0.2773501 ,
#        -0.21821789,  0.2       , -0.2       ,  0.2773501 , -0.4       ,
#        -0.2236068 , -0.40824829, -0.26726124, -0.39223227, -0.31622777,
#        -0.43643578, -0.20851441, -0.41702883, -0.20851441, -0.41702883,
#        -0.19611614, -0.53881591, -0.35355339, -0.4       , -0.20412415,
#        -0.40824829,  0.21320072, -0.42640143,  0.21320072, -0.20412415,
#        -0.40824829,  0.21320072, -0.42640143,  0.21320072, -0.20412415,
#        -0.40824829,  0.21320072, -0.42640143,  0.21320072, -0.20412415,
#        -0.40824829,  0.21320072, -0.42640143,  0.21320072, -0.20412415,
#        -0.40824829,  0.21320072, -0.42640143,  0.21320072,  0.16666667,
#        -0.5       ,  0.18257419, -0.54772256,  0.24253563, -0.18569534,
#        -0.20851441,  0.20851441,  0.1796053 , -0.1796053 ,  0.20851441,
#        -0.20851441,  0.2773501 , -0.2773501 , -0.21320072, -0.42640143,
#        -0.2236068 , -0.4472136 ,  0.2773501 , -0.2773501 , -0.37139068,
#        -0.20851441, -0.2236068 ,  0.25819889, -0.19245009, -0.19245009,
#         0.25      , -0.37796447, -0.23570226, -0.23570226,  0.23570226,
#        -0.20851441,  0.20851441, -0.23570226,  0.21320072,  0.21320072,
#        -0.21320072, -0.20851441,  0.22941573, -0.21320072,  0.21821789,
#        -0.16222142, -0.38490018, -0.19245009,  0.19245009, -0.19245009,
#        -0.3592106 , -0.19245009, -0.38490018, -0.4       ,  0.2236068 ,
#        -0.21320072, -0.21320072, -0.20851441, -0.20851441, -0.4       ,
#        -0.20412415, -0.37139068,  0.40824829, -0.37796447, -0.24253563,
#        -0.39223227, -0.52223297])

# %%
import random
def sample_equally(X, Y):
    n1 = np.count_nonzero(Y)
    n0 = len(Y) - n1
    
    if n0 > n1:
        zs = np.arange(len(Y))[Y==0]
        rm_inds = zs[random.sample(range(n0),n0 - n1)]
    elif n1 > n0:
        nzs = (Y==1).nonzero()
        rm_inds = nzs[random.sample(range(n1), n1 - n0)]
        
    X = np.delete(X, rm_inds, axis=0)
    return X, np.delete(Y, rm_inds)

X_sampled, Y_sampled = sample_equally(X_torch, Y_torch)
# Out:
# (array([    0,     0,     0, ..., 87135, 87135, 87135]),
#  array([ 152,  228,  300, ..., 3081, 3257, 3895]))

# %%
X_all = np.concatenate([X_torch], 1)



run_nn(X_sampled, Y_sampled)
# Out:
# Creating kfold
# Folding
# Creating dataset
# Starting classifier
# Epoch 0
# Loss:  0.6930519342422485
# Loss:  0.6936595439910889
# Loss:  0.6933972835540771
# Loss:  0.6930513381958008
# {0}
# epoch test accuracy:  0.49741794812944684
# Epoch 1
# Loss:  0.6950222253799438
# Loss:  0.6932680010795593
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-122-be80655c8c53> in <module>()
#       3
#       4
# ----> 5 run_nn(X_sampled, Y_sampled)
#
# <ipython-input-10-63a398ce433f> in run_nn(X, Y, n_folds)
#      17         dataset = MyDataset(x_train, y_train, x_test, y_test)
#      18
# ---> 19         p_corrects.append(nn_classify(dataset))
#      20
#      21     return p_corrects
#
# <ipython-input-98-0d9a6993b171> in nn_classify(dataset)
#      74             optimizer.zero_grad()
#      75
# ---> 76             y_pred = net(inputs)
#      77
#      78             loss = criterion(y_pred, labels)
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# <ipython-input-98-0d9a6993b171> in forward(self, x)
#      42     def forward(self, x):
#      43         out = x.view(x.shape[0], -1)
# ---> 44         out = F.sigmoid(self.fc1(out))
#      45         out = F.sigmoid(self.fc3(out))
#      46
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      53
#      54     def forward(self, input):
# ---> 55         return F.linear(input, self.weight, self.bias)
#      56
#      57     def __repr__(self):
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#     833     if input.dim() == 2 and bias is not None:
#     834         # fused op is marginally faster
# --> 835         return torch.addmm(bias, input, weight.t())
#     836
#     837     output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
run_nn(features_no_text.todense(), Y_torch)
# Out:
# Creating kfold
# Folding
# Creating dataset
# Starting classifier
# Epoch 0
# Loss:  0.7149047255516052
# Loss:  0.6235060095787048
# Loss:  0.6768231987953186
# Loss:  0.71131432056427
# Loss:  0.6950801610946655
# Loss:  0.6613279581069946
# Loss:  0.6960049867630005
# Loss:  0.6963950395584106
# {0}
# epoch test accuracy:  0.5448225007900558
# Epoch 1
# Loss:  0.6876341104507446
# Loss:  0.6950832605361938
# Loss:  0.6990638971328735
# Loss:  0.6955081820487976
# Loss:  0.6845874786376953
# Loss:  0.6691179275512695
# Loss:  0.6877443790435791
# Loss:  0.7109284996986389
# {0, 1}
# epoch test accuracy:  0.560570947013589
# Epoch 2
# Loss:  0.6226317882537842
# Loss:  0.5901790261268616
# Loss:  0.6484287977218628
# Loss:  0.6113727688789368
# Loss:  0.7064258456230164
# Loss:  0.7472276091575623
# Loss:  0.7828632593154907
# Loss:  0.5210118889808655
# {0, 1}
# epoch test accuracy:  0.6242494469609186
# Epoch 3
# Loss:  0.5328080058097839
# Loss:  0.5145958662033081
# Loss:  0.5972114205360413
# Loss:  0.7431961297988892
# Loss:  0.5098970532417297
# Loss:  0.626076877117157
# Loss:  0.7131136655807495
# Loss:  0.5540869832038879
# {0, 1}
# epoch test accuracy:  0.5561993047508691
# Epoch 4
# Loss:  0.6234750747680664
# Loss:  0.6351786255836487
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-d6490765f0dc> in <module>()
# ----> 1 run_nn(features_no_text.todense(), Y_torch)
#
# <ipython-input-10-63a398ce433f> in run_nn(X, Y, n_folds)
#      17         dataset = MyDataset(x_train, y_train, x_test, y_test)
#      18
# ---> 19         p_corrects.append(nn_classify(dataset))
#      20
#      21     return p_corrects
#
# <ipython-input-93-aad0cbe083b7> in nn_classify(dataset)
#      84
#      85
# ---> 86             loss.backward()
#      87
#      88             optimizer.step()
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/autograd/variable.py in backward(self, gradient, retain_graph, create_graph, retain_variables)
#     165                 Variable.
#     166         """
# --> 167         torch.autograd.backward(self, gradient, retain_graph, create_graph, retain_variables)
#     168
#     169     def register_hook(self, hook):
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(variables, grad_variables, retain_graph, create_graph, retain_variables)
#      97
#      98     Variable._execution_engine.run_backward(
# ---> 99         variables, grad_variables, retain_graph)
#     100
#     101
#
# KeyboardInterrupt:

# %%
run_nn(features_no_text.todense(), Y_torch)
# Out:
# Creating kfold
# Folding
# Creating dataset
# Starting classifier
# Epoch 0
# Loss:  0.6920455694198608
# Loss:  0.7073584794998169
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-202-d6490765f0dc> in <module>()
# ----> 1 run_nn(features_no_text.todense(), Y_torch)
#
# <ipython-input-10-63a398ce433f> in run_nn(X, Y, n_folds)
#      17         dataset = MyDataset(x_train, y_train, x_test, y_test)
#      18
# ---> 19         p_corrects.append(nn_classify(dataset))
#      20
#      21     return p_corrects
#
# <ipython-input-201-98fa4e226664> in nn_classify(dataset)
#      72             inputs, labels = data
#      73             inputs, labels = Variable(inputs), Variable(labels)
# ---> 74             optimizer.zero_grad()
#      75
#      76             y_pred = net(inputs)
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/optim/optimizer.py in zero_grad(self)
#     114                 if p.grad is not None:
#     115                     if p.grad.volatile:
# --> 116                         p.grad.data.zero_()
#     117                     else:
#     118                         data = p.grad.data
#
# KeyboardInterrupt:

# %%
no_text_X_sampled, Y_torch_sampled = sample_equally(features_no_text.todense(), Y_torch)

# %%
run_nn(no_text_X_sampled, Y_torch_sampled)
# Out:
# Creating kfold
# Folding
# Creating dataset
# Starting classifier
# Epoch 0
# Loss:  0.682822048664093
# Loss:  0.695063591003418
# Loss:  0.6892836689949036
# Loss:  0.6852731704711914
# {0, 1}
# epoch test accuracy:  0.5200826256598577
# Epoch 1
# Loss:  0.6807538270950317
# Loss:  0.6799079179763794
# Loss:  0.6930932402610779
# Loss:  0.6769686937332153
# {0, 1}
# epoch test accuracy:  0.5516984163415194
# Loss:  0.6804470419883728
# Loss:  0.6389520764350891
# Loss:  0.6088348031044006
# {0, 1}
# epoch test accuracy:  0.6885471654808354
# Epoch 19
# Loss:  0.6178008317947388
# Loss:  0.6522514224052429
# Loss:  0.6966003179550171
# Loss:  0.5898522138595581
# {0, 1}
# epoch test accuracy:  0.6896947440899701
# Epoch 20
# Loss:  0.544110894203186
# Loss:  0.6541911363601685
# Loss:  0.634025514125824
# Loss:  0.5741124749183655
# {0, 1}
# epoch test accuracy:  0.6774156529722286
# Epoch 21
# Loss:  0.6641599535942078
# Loss:  0.5610388517379761
# Loss:  0.5452856421470642
# Loss:  0.6562170386314392
# {0, 1}
# epoch test accuracy:  0.6921046591691531
# Epoch 22
# Loss:  0.5093444585800171
# Loss:  0.7557469606399536
# Loss:  0.6800951361656189
# Loss:  0.6200177669525146
# {0, 1}
# epoch test accuracy:  0.6950883635529034
# Epoch 23
# Loss:  0.5869241952896118
# Loss:  0.5682754516601562
# Loss:  0.5222435593605042
# Loss:  0.640658974647522
# {0, 1}
# epoch test accuracy:  0.6989901308239614
# Epoch 24
# Loss:  0.5634352564811707
# Loss:  0.5939265489578247
# Loss:  0.6781622767448425
# Loss:  0.5870537757873535
# {0, 1}
# epoch test accuracy:  0.6974408997016296
# Epoch 25
# Loss:  0.633188784122467
# Loss:  0.6110715866088867
# Loss:  0.5241586565971375
# Loss:  0.6244087815284729
# {0, 1}
# epoch test accuracy:  0.6961785632315813
# Epoch 26
# Loss:  0.5872683525085449
# Loss:  0.5287939310073853
# Loss:  0.5876660943031311
# Loss:  0.6939105987548828
# {0, 1}
# epoch test accuracy:  0.6949736056919898
# Epoch 27
# Loss:  0.5749496817588806
# Loss:  0.598923921585083
# Loss:  0.47478699684143066
# Loss:  0.6517971158027649
# {0, 1}
# epoch test accuracy:  0.6913013541427587
# Epoch 28
# Loss:  0.6309514045715332
# Loss:  0.5900540351867676
# Loss:  0.6973128914833069
# Loss:  0.6476604342460632
# {0, 1}
# epoch test accuracy:  0.7047280238696351
# Epoch 29
# Loss:  0.6263570785522461
# Loss:  0.5886589288711548
# Loss:  0.5720006227493286
# Loss:  0.6310194134712219
# {0, 1}
# epoch test accuracy:  0.7053018131742025
# Epoch 30
# Loss:  0.651164710521698
# Loss:  0.5961146950721741
# Loss:  0.5340744256973267
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-128-bfaa79fbd7ce> in <module>()
# ----> 1 run_nn(no_text_X_sampled, Y_torch_sampled)
#
# <ipython-input-10-63a398ce433f> in run_nn(X, Y, n_folds)
#      17         dataset = MyDataset(x_train, y_train, x_test, y_test)
#      18
# ---> 19         p_corrects.append(nn_classify(dataset))
#      20
#      21     return p_corrects
#
# <ipython-input-127-a13e07525576> in nn_classify(dataset)
#      76             y_pred = net(inputs)
#      77
# ---> 78             loss = criterion(y_pred, labels)
#      79
#      80             if (i % 1000) == 1:
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     677         _assert_no_grad(target)
#     678         return F.cross_entropy(input, target, self.weight, self.size_average,
# --> 679                                self.ignore_index, self.reduce)
#     680
#     681
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/functional.py in cross_entropy(input, target, weight, size_average, ignore_index, reduce)
#    1159         >>> loss.backward()
#    1160     """
# -> 1161     return nll_loss(log_softmax(input, 1), target, weight, size_average, ignore_index, reduce)
#    1162
#    1163
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/functional.py in log_softmax(input, dim, _stacklevel)
#     784     if dim is None:
#     785         dim = _get_softmax_dim('log_softmax', input.dim(), _stacklevel)
# --> 786     return torch._C._nn.log_softmax(input, dim)
#     787
#     788
#
# KeyboardInterrupt:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
v = TfidfVectorizer(max_features=16384)

desc_features = v.fit_transform(succ_fail_only['desc'])
name_features = v.fit_transform(succ_fail_only['name'])

# %%
str_features = np.concatenate([desc_features.todense(), name_features.todense()], 1)

# %%
from scipy.sparse import hstack
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(512)
X_svd = svd.fit_transform(hstack([desc_features, name_features]))

# %%
from sklearn.decomposition import PCA

pca = PCA(512)
X_pca = pca.fit_transform(np.concatenate([str_features, features_no_text.todense()],1))

# %%
Y_torch.shape, name_features, desc_features
# Out:
# ((94928,), <94928x2048 sparse matrix of type '<class 'numpy.float64'>'
#  	with 333167 stored elements in Compressed Sparse Row format>, <94928x2048 sparse matrix of type '<class 'numpy.float64'>'
#  	with 1293431 stored elements in Compressed Sparse Row format>)

# %%
x_text_equal, y_text_equal= sample_equally(X_pca, Y_torch)
run_nn(x_text_equal, y_text_equal)
# Out:
# Creating kfold
# Folding
# Creating dataset
# Starting classifier
# Epoch 0
# Loss:  0.6891080141067505
# Loss:  0.6950901746749878
# Loss:  0.6897500157356262
# Loss:  0.7046384811401367
# {0, 1}
# epoch test accuracy:  0.5685104429653431
# Epoch 1
# Loss:  0.747378408908844
# Loss:  0.6142457723617554
# Loss:  0.6689587831497192
# Loss:  0.6869531869888306
# {0, 1}
# epoch test accuracy:  0.6470621987606151
# Epoch 2
# Loss:  0.6590135097503662
# Loss:  0.5931385159492493
# Loss:  0.5871032476425171
# Loss:  0.5200247168540955
# {0, 1}
# epoch test accuracy:  0.6913587330732155
# Epoch 3
# Loss:  0.6386398077011108
# Loss:  0.5571799874305725
# Loss:  0.6175441741943359
# Loss:  0.49692511558532715
# {0, 1}
# epoch test accuracy:  0.6873995868717007
# Epoch 4
# Loss:  0.5741495490074158
# Loss:  0.6250993013381958
# Loss:  0.5956780314445496
# Loss:  0.6424252390861511
# {0, 1}
# epoch test accuracy:  0.7070231810879045
# Epoch 5
# Loss:  0.5718030333518982
# Loss:  0.6099616289138794
# Loss:  0.6191413402557373
# Loss:  0.5381216406822205
# {0, 1}
# epoch test accuracy:  0.6976130364929998
# Loss:  0.5702037811279297
# Loss:  0.5720745325088501
# Loss:  0.5048580765724182
# {0, 1}
# epoch test accuracy:  0.7133922423686022
# Epoch 23
# Loss:  0.5622712969779968
# Loss:  0.5863481163978577
# Loss:  0.5499638915061951
# Loss:  0.7009204030036926
# {0, 1}
# epoch test accuracy:  0.7180399357355979
# Epoch 24
# Loss:  0.4988667070865631
# Loss:  0.5777130126953125
# Loss:  0.7085005640983582
# Loss:  0.5180834531784058
# {0, 1}
# epoch test accuracy:  0.7035804452605003
# Epoch 25
# Loss:  0.511732280254364
# Loss:  0.5170724987983704
# Loss:  0.6473402976989746
# Loss:  0.5751131176948547
# {0, 1}
# epoch test accuracy:  0.7218269451457425
# Epoch 26
# Loss:  0.6987195611000061
# Loss:  0.5368927717208862
# Loss:  0.6995391249656677
# Loss:  0.5722682476043701
# {0, 1}
# epoch test accuracy:  0.7201629561624971
# Epoch 27
# Loss:  0.49235963821411133
# Loss:  0.506930947303772
# Loss:  0.546606183052063
# Loss:  0.4774499535560608
# {0, 1}
# epoch test accuracy:  0.7192448932751894
# Epoch 28
# Loss:  0.6280017495155334
# Loss:  0.6001732349395752
# Loss:  0.6172422170639038
# Loss:  0.5743314623832703
# {0, 1}
# epoch test accuracy:  0.721482671563002
# Epoch 29
# Loss:  0.54893559217453
# Loss:  0.6500268578529358
# Loss:  0.5974744558334351
# Loss:  0.6072989702224731
# {0, 1}
# epoch test accuracy:  0.6943998163874225
# Epoch 30
# Loss:  0.6054008603096008
# Loss:  0.6534684300422668
# Loss:  0.6508283615112305
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-211-5820a3d64b4c> in <module>()
#       1 x_text_equal, y_text_equal= sample_equally(X_pca, Y_torch)
# ----> 2 run_nn(x_text_equal, y_text_equal)
#
# <ipython-input-10-63a398ce433f> in run_nn(X, Y, n_folds)
#      17         dataset = MyDataset(x_train, y_train, x_test, y_test)
#      18
# ---> 19         p_corrects.append(nn_classify(dataset))
#      20
#      21     return p_corrects
#
# <ipython-input-208-0f8d70214d12> in nn_classify(dataset)
#      74             optimizer.zero_grad()
#      75
# ---> 76             y_pred = net(inputs)
#      77
#      78             loss = criterion(y_pred, labels)
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# <ipython-input-208-0f8d70214d12> in forward(self, x)
#      42     def forward(self, x):
#      43         out = x.view(x.shape[0], -1)
# ---> 44         out = F.sigmoid(self.fc1(out))
#      45         out = F.sigmoid(self.fc3(out))
#      46
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     355             result = self._slow_forward(*input, **kwargs)
#     356         else:
# --> 357             result = self.forward(*input, **kwargs)
#     358         for hook in self._forward_hooks.values():
#     359             hook_result = hook(self, input, result)
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      53
#      54     def forward(self, input):
# ---> 55         return F.linear(input, self.weight, self.bias)
#      56
#      57     def __repr__(self):
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#     833     if input.dim() == 2 and bias is not None:
#     834         # fused op is marginally faster
# --> 835         return torch.addmm(bias, input, weight.t())
#     836
#     837     output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
run_classifier(X_svd, Y, RandomForestClassifier())
# Out:
# 	Fold accuracy: 0.675
# 	Fold accuracy: 0.690
# 	Fold accuracy: 0.681
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-167-e757c9899224> in <module>()
# ----> 1 run_classifier(X_svd, Y, RandomForestClassifier())
#
# <ipython-input-67-7c1f66775f8e> in inner(*args, **kwargs)
#       4     def inner(*args, **kwargs):
#       5         try:
# ----> 6             return fn(*args, **kwargs)
#       7         except Exception:
#       8             print(traceback.format_exc())
#
# <ipython-input-69-5cc05b53bc1e> in run_classifier(X, Y, clf, n_folds)
#      22         y_test = Y[test]
#      23
# ---> 24         clf.fit(x_train, y_train)
#      25
#      26         predY = clf.predict(x_test)
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     326                     t, self, X, y, sample_weight, i, len(trees),
#     327                     verbose=self.verbose, class_weight=self.class_weight)
# --> 328                 for i, t in enumerate(trees))
#     329
#     330             # Collect newly grown trees
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# --> 779             while self.dispatch_one_batch(iterator):
#     780                 self._iterating = True
#     781             else:
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     623                 return False
#     624             else:
# --> 625                 self._dispatch(tasks)
#     626                 return True
#     627
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     586         dispatch_timestamp = time.time()
#     587         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 588         job = self._backend.apply_async(batch, callback=cb)
#     589         self._jobs.append(job)
#     590
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     109     def apply_async(self, func, callback=None):
#     110         """Schedule a func to be run"""
# --> 111         result = ImmediateResult(func)
#     112         if callback:
#     113             callback(result)
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     330         # Don't delay the application, to avoid keeping the input
#     331         # arguments in memory
# --> 332         self.results = batch()
#     333
#     334     def get(self):
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     119             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     120
# --> 121         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     122     else:
#     123         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     788             sample_weight=sample_weight,
#     789             check_input=check_input,
# --> 790             X_idx_sorted=X_idx_sorted)
#     791         return self
#     792
#
# /media/sdb1/nfs/iped/miniconda2/envs/py3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     360                                            min_impurity_split)
#     361
# --> 362         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     363
#     364         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:
